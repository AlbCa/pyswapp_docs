# %%
import sys
import copy
import matplotlib.pyplot as plt
import numpy as np

sys.path.insert(1, '../swa')

from geometry import *
from utils import *
from _stream import SeismicStream
from _curve import Curve
from _combineCurves import CombineCurves


# %% Create and apply filter in fk domain

# directories
prj_dir = '../data/syn_data'
path2raw = os.path.join(prj_dir,'raw')
path2geom = f'{prj_dir}/geometry_test.csv'
path2fk = f'{prj_dir}/proc/fk_filter/fkfilter_test2.txt'
ext = '.sgy' # shot file extension

# processing and plotting settings
settings = create_settings_dict(trafo = 'fdbf',             # transformation type
                         zero_padding=False, freq_step=0.5,  # zero padding
                         normalize = True, local_max = True, # amplitude normalization
                         picking = 'manual',                # picking mode ("manual" or "auto")
                         fmin=3, fmax=60,                  # frequency range
                         vmin=50, vmax=1000, velstep=1)     # testing phase velocity range and step
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.

# %%
# get paths to shot files, survey geometry from geometry.csv
shot_files, source_coordinates, receiver_coordinates = read_geometry(path2geom)
path2sht = get_shotfiles_from_geometry(path2raw, shot_files, extension = ext, sort_ascending = True)

mintrace = 2
maxtrace = 50

min_offset, max_offset = 1, 40


# run the fk filtering for each file
for i in range(0,len(path2sht)):

    stream = SeismicStream(path2sht[i][0], settings) # record
    trace_select = range(mintrace, maxtrace)
    #stream._select_traces(trace_select=trace_select)

    stream._trim_by_offsets(min_offset, max_offset)
    
    #oids = np.argwhere((offset >= -max_offset) & (offset <= -min_offset))[:, 0]
    #stream._select_traces(oids)

    stream_cp = copy.deepcopy(stream)

    # load fk filter from file and apply
    #stream_cp._fk_filter_from_file(fname='test_fk.txt', show=False)

    # pick fk filter and apply
    stream_cp._fk_filter_from_pick(fname=path2fk, show=True)
    #stream_cp._fk_filter_from_pick(show=False) # if fname is not provided, no file will be generated

    # show the seismogram
    # fig,ax = plt.subplots()
    # stream._plotSeismogram(axes = ax, show_map = False, color = 'r')
    # stream_cp._plotSeismogram(axes=ax, show_map=False, color='b')
    # plt.show()

    # show the dispersion image
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    stream._apply_trafo(do_pick=False)
    stream._plotDispersionImage(axes=ax[0])
    stream_cp._apply_trafo(do_pick=False)
    stream_cp._plotDispersionImage(axes=ax[1])
    plt.tight_layout()
    plt.show()
# Out:
# You pressed t.
# You pressed e. Process stopped.
# /home/alberto/anaconda3/envs/swa/lib/python3.9/site-packages/matplotlib/contour.py:1568: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.zmax = z.max().astype(float)
# /home/alberto/anaconda3/envs/swa/lib/python3.9/site-packages/matplotlib/contour.py:1569: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.zmin = z.min().astype(float)
# /home/alberto/anaconda3/envs/swa/lib/python3.9/site-packages/numpy/ma/core.py:2820: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data = np.array(data, dtype=dtype, copy=copy,
# You pressed t.
# /home/alberto/GitHub/sw/tutorial/../swa/_stream.py:1377: UserWarning: File already exists. Fk filter will be appended.
#   warnings.warn('File already exists. Fk filter will be appended.')
# You pressed e. Process stopped.
# You pressed t.
# You pressed e. Process stopped.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 18
#      15 trace_select = range(mintrace, maxtrace)
#      16 #stream._select_traces(trace_select=trace_select)
# ---> 18 stream._trim_by_offsets(min_offset, max_offset)
#      20 #oids = np.argwhere((offset >= -max_offset) & (offset <= -min_offset))[:, 0]
#      21 #stream._select_traces(oids)
#      23 stream_cp = copy.deepcopy(stream)
#
# File ~/GitHub/sw/tutorial/../swa/_stream.py:685, in SeismicStream._trim_by_offsets(self, min_offset, max_offset)
#     683 # update
#     684 self._pst = st_new
# --> 685 self._update_params_from_stream(st_new)
#
# File ~/GitHub/sw/tutorial/../swa/_stream.py:411, in SeismicStream._update_params_from_stream(self, st)
#     409 def _update_params_from_stream(self, st):
#     410     """update shot parameters"""
# --> 411     self.npts = len(st[0].data)
#     412     self.nchannels = len(st)
#     414     self.receiver = self._receiver()
#
# File ~/anaconda3/envs/swa/lib/python3.9/site-packages/obspy/core/stream.py:645, in Stream.__getitem__(self, index)
#     643     return self.__class__(traces=self.traces.__getitem__(index))
#     644 else:
# --> 645     return self.traces.__getitem__(index)
#
# IndexError: list index out of range
